# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
OCR a PDF, reflow line-wrapped OCR text into running text, then split into sentences.
Output table: 1 sentence = 1 row, with metadata and start/end page.

Outputs:
- .txt (full reflowed text with page markers)
- .csv
- .parquet
"""

from __future__ import annotations

import argparse
import re
from pathlib import Path
from typing import Optional, Dict, Any, List, Tuple

import pandas as pd
from tqdm import tqdm
import ocrmypdf

# spaCy for sentence segmentation (French)
import spacy
# if needed install the French model
# python -m spacy download fr_core_news_sm



# ---------------------------
# Heuristics / parsing helpers
# ---------------------------

PART_PATTERNS = [
    re.compile(r"^\s*(Première|Deuxième|Troisième|Quatrième|Cinquième)\s+partie\s*$", re.IGNORECASE),
    re.compile(r"^\s*Partie\s+\w+\s*$", re.IGNORECASE),
]

CHAPTER_PATTERNS = [
    re.compile(r"^\s*chapitre\s+(\d+)\s*$", re.IGNORECASE),
    re.compile(r"^\s*(\d+)\s*$"),  # lone number line (common in novels)
]

PRINTED_PAGE_PATTERN = re.compile(r"^\s*(\d{1,4})\s*$")


def normalize_line(s: str) -> str:
    s = s.replace("\u00ad", "")  # soft hyphen
    s = s.replace("\ufeff", "")  # BOM
    s = s.replace("\u200b", "")  # zero-width space
    s = re.sub(r"[ \t]+", " ", s)
    return s.strip()


def looks_like_header_footer(line: str) -> bool:
    # Conservative: lone digits likely page numbers
    if not line:
        return True
    if PRINTED_PAGE_PATTERN.fullmatch(line) and len(line) <= 4:
        return True
    return False


def update_structure(line: str, current: Dict[str, Optional[str]]) -> None:
    for pat in PART_PATTERNS:
        if pat.match(line):
            current["part"] = line
            current["chapter"] = None
            return

    for pat in CHAPTER_PATTERNS:
        m = pat.match(line)
        if m:
            chap = m.group(1) if m.groups() else line
            current["chapter"] = f"Chapter {chap}"
            return


def extract_printed_page_candidate(lines: List[str]) -> Optional[str]:
    candidates = []
    if lines:
        top = lines[:3]
        bottom = lines[-3:]
        for l in top + bottom:
            l2 = normalize_line(l)
            if PRINTED_PAGE_PATTERN.fullmatch(l2):
                candidates.append(l2)
    return candidates[-1] if candidates else None


# ---------------------------
# OCR + extraction
# ---------------------------
    
def ocr_pdf_to_searchable_pdf(
    input_pdf: Path,
    output_pdf: Path,
    lang: str = "fra",
    deskew: bool = True,
    rotate_pages: bool = True,
    force_ocr: bool = False,
    jobs: int = 2,
) -> None:
    output_pdf.parent.mkdir(parents=True, exist_ok=True)
    ocrmypdf.ocr(
        str(input_pdf),
        str(output_pdf),
        language=lang,
        deskew=deskew,
        rotate_pages=rotate_pages,
        force_ocr=force_ocr,
        skip_text=True,
        jobs=jobs,
        output_type="pdf",
        progress_bar=True,
    )


def extract_text_per_page(searchable_pdf: Path) -> List[str]:
    import subprocess
    import tempfile
    from pathlib import Path

    with tempfile.TemporaryDirectory() as td:
        td = Path(td)
        out_txt = td / "out.txt"

        cmd = ["pdftotext", "-layout", str(searchable_pdf), str(out_txt)]
        subprocess.run(cmd, check=True)

        full_text = out_txt.read_text(encoding="utf-8", errors="replace")

    pages = full_text.split("\f")
    if pages and not pages[-1].strip():
        pages = pages[:-1]
    return pages


# ---------------------------
# Reflow: turn OCR lines into running text with provenance
# ---------------------------

SENTENCE_END_RE = re.compile(r"[.!?…]+[\"”’»)]?\s*$")
DIALOGUE_DASH_RE = re.compile(r"^\s*[-–—]\s*")  # French dialogue dash lines
HARD_BREAK_RE = re.compile(r"^\s*$")

def should_join_with_space(prev: str, cur: str) -> bool:
    """
    Decide whether to join prev + cur with a space, no space, or paragraph break.
    We handle hyphenation separately.
    """
    if not prev:
        return False

    # If prev ends like a sentence or strong punctuation, likely a new sentence/paragraph can start.
    if SENTENCE_END_RE.search(prev):
        return False

    # If current line looks like a dialogue dash, keep break (often new utterance).
    if DIALOGUE_DASH_RE.match(cur):
        return False

    # Otherwise, typical line-wrap: join.
    return True


def reflow_pages_with_provenance(
    page_texts: List[str],
    drop_headers_footers: bool = True,
    drop_empty: bool = True,
) -> List[Dict[str, Any]]:
    """
    Produce a sequence of "chunks" (running text segments) with page provenance.
    Each chunk is a piece of continuous text we’ll later sentence-split.

    Returns list of dicts:
      { "text": ..., "start_pdf_page": i, "end_pdf_page": j }
    """
    chunks: List[Dict[str, Any]] = []

    current_text = ""
    current_start_page = 1
    current_end_page = 1

    for i, ptxt in enumerate(tqdm(page_texts, desc="Reflowing pages")):
        pdf_page = i + 1
        raw_lines = ptxt.splitlines()
        lines = [normalize_line(x) for x in raw_lines]

        # filter
        filtered: List[str] = []
        for l in lines:
            if drop_empty and not l:
                continue
            if drop_headers_footers and looks_like_header_footer(l):
                continue
            filtered.append(l)

        # page -> running text
        prev_line = ""
        for l in filtered:
            # paragraph break marker from blank lines would have been removed if drop_empty=True
            # If you keep empty lines, treat them as hard breaks.
            if HARD_BREAK_RE.match(l):
                # flush current chunk
                if current_text.strip():
                    chunks.append(
                        {"text": current_text.strip(), "start_pdf_page": current_start_page, "end_pdf_page": current_end_page}
                    )
                current_text = ""
                prev_line = ""
                current_start_page = pdf_page
                current_end_page = pdf_page
                continue

            # hyphenation fix: if previous ends with "-" and current starts with a letter, merge without space and drop hyphen
            if current_text.endswith("-") and l and re.match(r"^[A-Za-zÀ-ÖØ-öø-ÿ]", l):
                current_text = current_text[:-1] + l
            else:
                if current_text and should_join_with_space(prev_line, l):
                    current_text += " " + l
                elif current_text:
                    # keep a newline as a soft paragraph/utterance boundary marker
                    current_text += "\n" + l
                else:
                    current_text = l

            prev_line = l
            current_end_page = pdf_page

        # At page boundary:
        # If we are mid-sentence, we want to continue into next page.
        # If the current_text ends with sentence-final punctuation, we can flush now for cleaner provenance.
        if current_text.strip() and SENTENCE_END_RE.search(current_text.splitlines()[-1]):
            chunks.append({"text": current_text.strip(), "start_pdf_page": current_start_page, "end_pdf_page": current_end_page})
            current_text = ""
            prev_line = ""
            current_start_page = pdf_page + 1
            current_end_page = pdf_page + 1

    # flush any remaining
    if current_text.strip():
        chunks.append({"text": current_text.strip(), "start_pdf_page": current_start_page, "end_pdf_page": current_end_page})

    return chunks


# ---------------------------
# Structure tracking + sentence splitting
# ---------------------------

def build_sentences_table(
    page_texts: List[str],
    book_title: str,
    keep_headers_footers: bool = False,
    keep_empty: bool = False,
) -> pd.DataFrame:
    # Load spaCy French pipeline
    nlp = spacy.load("fr_core_news_sm")
    # Ensure sentence boundaries exist (they do in the model, but keep it explicit)
    if "parser" not in nlp.pipe_names and "senter" not in nlp.pipe_names:
        nlp.add_pipe("sentencizer")

    # First, we’ll also track part/chapter by scanning normalized lines in order (page by page).
    current = {"part": None, "chapter": None}
    page_struct: Dict[int, Dict[str, Optional[str]]] = {}

    for i, ptxt in enumerate(page_texts):
        pdf_page = i + 1
        raw_lines = ptxt.splitlines()
        norm_lines = [normalize_line(x) for x in raw_lines]
        for l in norm_lines:
            if not l:
                continue
            update_structure(l, current)
        page_struct[pdf_page] = {"part": current["part"], "chapter": current["chapter"]}

    # Reflow text into chunks with start/end page provenance
    chunks = reflow_pages_with_provenance(
        page_texts=page_texts,
        drop_headers_footers=not keep_headers_footers,
        drop_empty=not keep_empty,
    )

    rows: List[Dict[str, Any]] = []
    sent_id = 0

    for ch in tqdm(chunks, desc="Sentence splitting"):
        text = ch["text"]
        start_p = int(ch["start_pdf_page"])
        end_p = int(ch["end_pdf_page"])

        # Choose metadata from the sentence start page (most consistent)
        part = page_struct.get(start_p, {}).get("part")
        chapter = page_struct.get(start_p, {}).get("chapter")

        # Split sentences with spaCy
        doc = nlp(text.replace("\n", " "))  # newlines are typically not meaningful after reflow
        for s in doc.sents:
            sent = s.text.strip()
            if not sent:
                continue
            sent_id += 1
            rows.append(
                {
                    "sentence_id": sent_id,
                    "book_title": book_title,
                    "part": part,
                    "chapter": chapter,
                    "start_pdf_page": start_p,
                    "end_pdf_page": end_p,
                    "text": sent,
                }
            )

    return pd.DataFrame(rows)

from pathlib import Path

input_pdf = Path("La-ballade-de-Pern-intégrale-McCaffrey_-Anne-La-Ballade-de-Pern_-2015-12-21-9782823821758-bc3525592e.pdf")
out_dir = Path("")
book_title = "La Ballade de Pern — Intégrale (Anne McCaffrey)"

out_dir.mkdir(parents=True, exist_ok=True)

searchable_pdf = out_dir / (input_pdf.stem + ".searchable.pdf")

# %%
# Step 1: OCR
ocr_pdf_to_searchable_pdf(
    input_pdf=input_pdf,
    output_pdf=searchable_pdf,
    lang="fra",
    force_ocr=False,
    jobs=2,
)

# Step 2: Extract text
page_texts = extract_text_per_page(searchable_pdf)

# Step 3: Build sentences
df = build_sentences_table(
    page_texts=page_texts,
    book_title=book_title
)

# Step 4: Save
df.to_csv(out_dir / "sentences.csv", index=False)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   1%   48/4613 0:00:30
# Scanning contents    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   2%   84/4613 0:00:32
# Scanning contents    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   3%  123/4613 0:00:33
# Scanning contents    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   4%  164/4613 0:00:33
# Scanning contents    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   4%  195/4613 0:00:33
# Scanning contents    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   5%  226/4613 0:00:33
# Scanning contents    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   6%  263/4613 0:00:33
# Scanning contents    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   6%  293/4613 0:00:32
# Scanning contents    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7%  328/4613 0:00:32
# Scanning contents    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  364/4613 0:00:32
# Scanning contents    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   9%  398/4613 0:00:31
# Scanning contents    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   9%  431/4613 0:00:31
# Scanning contents    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  10%  463/4613 0:00:31
# Scanning contents    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  11%  503/4613 0:00:31
# Scanning contents    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  12%  535/4613 0:00:30
# Scanning contents    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  12%  568/4613 0:00:30
# Scanning contents    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  13%  604/4613 0:00:30
# Scanning contents    ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  640/4613 0:00:30
# Scanning contents    ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  15%  682/4613 0:00:29
# Scanning contents    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  15%  714/4613 0:00:29
# Scanning contents    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  16%  751/4613 0:00:29
# Scanning contents    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  17%  790/4613 0:00:29
# Scanning contents    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  18%  814/4613 0:00:29
# Scanning contents    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  18%  846/4613 0:00:29
# Scanning contents    ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  19%  882/4613 0:00:28
# Scanning contents    ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  913/4613 0:00:28
# Scanning contents    ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21%  954/4613 0:00:28
# Scanning contents    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  22%  994/4613 0:00:27
# Scanning contents    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  22% 1025/4613 0:00:27
# Scanning contents    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  23% 1059/4613 0:00:27
# Scanning contents    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  24% 1095/4613 0:00:27
# Scanning contents    ━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  24% 1128/4613 0:00:26
# Scanning contents    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  25% 1168/4613 0:00:26
# Scanning contents    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  26% 1201/4613 0:00:26
# Scanning contents    ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  27% 1235/4613 0:00:26
# Scanning contents    ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  27% 1268/4613 0:00:25
# Scanning contents    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1311/4613 0:00:25
# Scanning contents    ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% 1348/4613 0:00:25
# Scanning contents    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1384/4613 0:00:25
# Scanning contents    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  31% 1419/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  31% 1446/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  32% 1484/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━  33% 1513/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━  33% 1543/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━  34% 1574/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━  35% 1601/4613 0:00:24
# Scanning contents    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━  35% 1633/4613 0:00:23
# Scanning contents    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━  36% 1662/4613 0:00:23
# Scanning contents    ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━  37% 1696/4613 0:00:23
# Scanning contents    ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1734/4613 0:00:23
# Scanning contents    ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  39% 1780/4613 0:00:22
# Scanning contents    ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  39% 1813/4613 0:00:22
# Scanning contents    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  40% 1846/4613 0:00:22
# Scanning contents    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  41% 1886/4613 0:00:21
# Scanning contents    ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━  42% 1922/4613 0:00:21
# Scanning contents    ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━  42% 1953/4613 0:00:21
# Scanning contents    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━  43% 1988/4613 0:00:21
# Scanning contents    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━  44% 2018/4613 0:00:20
# Scanning contents    ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━  45% 2058/4613 0:00:20
# Scanning contents    ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  46% 2100/4613 0:00:20
# Scanning contents    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  46% 2141/4613 0:00:19
# Scanning contents    ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2179/4613 0:00:19
# Scanning contents    ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━  48% 2210/4613 0:00:19
# Scanning contents    ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━  49% 2247/4613 0:00:19
# Scanning contents    ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━  49% 2280/4613 0:00:19
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 2310/4613 0:00:18
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  51% 2338/4613 0:00:18
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━  51% 2369/4613 0:00:18
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━  52% 2397/4613 0:00:18
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2422/4613 0:00:18
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2453/4613 0:00:17
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━  54% 2482/4613 0:00:17
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━  55% 2516/4613 0:00:17
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━  56% 2561/4613 0:00:17
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━  56% 2597/4613 0:00:16
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━  57% 2625/4613 0:00:16
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━  58% 2659/4613 0:00:16
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━  58% 2694/4613 0:00:16
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━  59% 2727/4613 0:00:15
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━  60% 2764/4613 0:00:15
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2796/4613 0:00:15
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━  61% 2830/4613 0:00:15
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━  62% 2860/4613 0:00:15
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━  63% 2894/4613 0:00:14
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━  64% 2931/4613 0:00:14
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2963/4613 0:00:14
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━  65% 2999/4613 0:00:13
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━  66% 3037/4613 0:00:13
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━  67% 3069/4613 0:00:13
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━  67% 3095/4613 0:00:13
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━  68% 3126/4613 0:00:13
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━  68% 3158/4613 0:00:12
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━  69% 3186/4613 0:00:12
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━  70% 3221/4613 0:00:12
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━  70% 3251/4613 0:00:12
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━  71% 3277/4613 0:00:11
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━  72% 3308/4613 0:00:11
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━  72% 3338/4613 0:00:11
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  73% 3365/4613 0:00:11
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3394/4613 0:00:10
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━  74% 3424/4613 0:00:10
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━  75% 3455/4613 0:00:10
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━  76% 3484/4613 0:00:10
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━  76% 3525/4613 0:00:09
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━  77% 3556/4613 0:00:09
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━  78% 3592/4613 0:00:09
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━  79% 3627/4613 0:00:08
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━  79% 3655/4613 0:00:08
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━  80% 3688/4613 0:00:08
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━  81% 3724/4613 0:00:08
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3758/4613 0:00:07
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  82% 3797/4613 0:00:07
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━  83% 3836/4613 0:00:07
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━  84% 3867/4613 0:00:06
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━  85% 3902/4613 0:00:06
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━  85% 3929/4613 0:00:06
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━  86% 3963/4613 0:00:06
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  87% 3992/4613 0:00:05
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  87% 4024/4613 0:00:05
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━  88% 4060/4613 0:00:05
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━  89% 4085/4613 0:00:05
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━  89% 4119/4613 0:00:04
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━  90% 4151/4613 0:00:04
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  91% 4181/4613 0:00:04
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━  91% 4213/4613 0:00:04
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━  92% 4250/4613 0:00:03
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% 4278/4613 0:00:03
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% 4312/4613 0:00:03
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━  94% 4342/4613 0:00:03
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━  95% 4374/4613 0:00:02
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━  95% 4404/4613 0:00:02
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━  96% 4439/4613 0:00:02
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━  97% 4467/4613 0:00:02
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  98% 4500/4613 0:00:01
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  98% 4524/4613 0:00:01
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸  99% 4561/4613 0:00:01
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4593/4613 0:00:01
# Scanning contents    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 4613/4613 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# [tesseract] Error during processing.
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# [tesseract] Error during processing.
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    0/4613 -:--:--
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%    3/4613 0:00:46
# OCR                  ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   6%  254/4613 0:01:42
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# OCR                  ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   8%  369/4613 0:01:09
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  13%  595/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14%  641/4613 0:00:13
# OCR                  ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  920/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  20%  942/4613 0:00:41
# OCR                  ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21%  970/4613 0:00:51
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# OCR                  ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  28% 1286/4613 0:00:11
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:46
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━  30% 1401/4613 0:00:56
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  38% 1768/4613 0:00:42
# OCR                  ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  45% 2092/4613 0:00:29
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# OCR                  ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━  47% 2167/4613 0:00:28
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━  52% 2406/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  53% 2434/4613 0:00:17
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━  56% 2572/4613 0:00:38
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━  61% 2801/4613 0:00:20
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2943/4613 0:00:14
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━  64% 2966/4613 0:00:13
# ...
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━  74% 3398/4613 0:00:19
# [tesseract] lots of diacritics - possibly poor OCR
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━  80% 3705/4613 0:00:08
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  81% 3752/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━  82% 3793/4613 0:00:13
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  90% 4163/4613 0:00:04
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━  91% 4193/4613 0:00:07
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4607/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 100% 4612/4613 0:00:01
# OCR                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 4613/4613 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# Linearizing          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%   0/100 -:--:--
# Linearizing          ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  17%  17/100 0:00:01
# Linearizing          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 100/100 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# Recompressing JPEGs  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# Recompressing JPEGs  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# Deflating JPEGs      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0%  0/25 -:--:--
# Deflating JPEGs      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━  88% 22/25 0:00:01
# Deflating JPEGs      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 25/25 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may
# help.
# JBIG2                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# JBIG2                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0/0 -:--:--
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2089073/2794419324.py in <module>
#       9
#      10 # Step 2: Extract text
# ---> 11 page_texts = extract_text_per_page(searchable_pdf)
#      12
#      13 # Step 3: Build sentences
#
# /tmp/ipykernel_2089073/3676868986.py in extract_text_per_page(searchable_pdf)
#     125         cmd = ["pdftotext", "-layout", str(searchable_pdf), str(out_txt)]
#     126         subprocess.run(cmd, check=True)
# --> 127         full_text = out_txt.read_text(encoding="utf-8", errors="replace")
#     128
#     129     pages = full_text.split("\f")
#
# AttributeError: 'str' object has no attribute 'read_text'
