# %%
# !pip install pandas tqdm spacy pyarrow ocrmypdf
# !python -m spacy download fr_core_news_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/marc-at/.local/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: tqdm in /home/marc-at/.local/lib/python3.10/site-packages (4.67.3)
# Requirement already satisfied: spacy in /home/marc-at/.local/lib/python3.10/site-packages (3.8.11)
# Requirement already satisfied: pyarrow in /home/marc-at/.local/lib/python3.10/site-packages (23.0.1)
# Requirement already satisfied: ocrmypdf in /home/marc-at/.local/lib/python3.10/site-packages (16.13.0)
# Requirement already satisfied: numpy>=1.22.4 in /home/marc-at/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/marc-at/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/marc-at/.local/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (0.24.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (82.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/marc-at/.local/lib/python3.10/site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/marc-at/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/marc-at/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/marc-at/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/marc-at/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/marc-at/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/marc-at/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/marc-at/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marc-at/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/marc-at/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/marc-at/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in /home/marc-at/.local/lib/python3.10/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/marc-at/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/marc-at/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in /home/marc-at/.local/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (2.1.0)
# Requirement already satisfied: img2pdf>=0.5 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (0.6.3)
# Requirement already satisfied: pdfminer-six>=20220319 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (20260107)
# Requirement already satisfied: pi-heif in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (1.3.0)
# Requirement already satisfied: pikepdf>=10 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (10.3.0)
# Requirement already satisfied: pillow>=10.0.1 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (12.1.1)
# Requirement already satisfied: pluggy>=1 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (1.6.0)
# Requirement already satisfied: rich>=13 in /home/marc-at/.local/lib/python3.10/site-packages (from ocrmypdf) (14.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /home/marc-at/.local/lib/python3.10/site-packages (from pdfminer-six>=20220319->ocrmypdf) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in /home/marc-at/.local/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.0.0)
# Requirement already satisfied: pycparser in /home/marc-at/.local/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (3.0)
# Requirement already satisfied: Deprecated in /home/marc-at/.local/lib/python3.10/site-packages (from pikepdf>=10->ocrmypdf) (1.3.1)
# Requirement already satisfied: lxml>=4.8 in /usr/lib/python3/dist-packages (from pikepdf>=10->ocrmypdf) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/marc-at/.local/lib/python3.10/site-packages (from rich>=13->ocrmypdf) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/marc-at/.local/lib/python3.10/site-packages (from rich>=13->ocrmypdf) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/marc-at/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf) (0.1.2)
# Requirement already satisfied: click>=8.2.1 in /home/marc-at/.local/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/marc-at/.local/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/marc-at/.local/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/marc-at/.local/lib/python3.10/site-packages (from jinja2->spacy) (3.0.3)
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
# /home/marc-at/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:184: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fr-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.8.0/fr_core_news_sm-3.8.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 31.5 MB/s  0:00:008.6 MB/s eta 0:00:0101
# WARNING: Error parsing dependencies of send2trash: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     sys-platform (=="darwin") ; extra == 'objc'
#                  ~^
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import re
import subprocess
import tempfile
from pathlib import Path
from typing import Optional, Dict, Any, List

import pandas as pd
from tqdm import tqdm
import spacy


# =========================
# LOAD SPACY MODEL
# =========================

try:
    nlp = spacy.load("fr_core_news_sm", disable=["ner"])
except OSError:
    raise RuntimeError(
        "Le modèle spaCy 'fr_core_news_sm' n'est pas installé.\n"
        "Exécutez : python -m spacy download fr_core_news_sm"
    )

if "parser" not in nlp.pipe_names and "senter" not in nlp.pipe_names:
    nlp.add_pipe("sentencizer")


# =========================
# PATTERNS
# =========================

PART_PATTERNS = [
    re.compile(r"^\s*(Première|Deuxième|Troisième|Quatrième|Cinquième)\s+partie\s*$", re.IGNORECASE),
    re.compile(r"^\s*Partie\s+\w+\s*$", re.IGNORECASE),
]

CHAPTER_PATTERNS = [
    re.compile(r"^\s*chapitre\s+(\d+)\s*$", re.IGNORECASE),
    re.compile(r"^\s*(\d+)\s*$"),
]

PRINTED_PAGE_PATTERN = re.compile(r"^\s*(\d{1,4})\s*$")

# détecte des lignes comme :
# La Ballade de Pern - Tome 1 L’AUBE DES DRAGONS
# La Ballade de Pern – Tome 12 ...
# Tome 3 ...
TOME_PATTERNS = [
    re.compile(
        r"^\s*(La\s+Ballade\s+de\s+Pern\s*[-–—]\s*)?Tome\s+(\d{1,2})\s*[:\-–—]?\s*(.+?)\s*$",
        re.IGNORECASE
    ),
    re.compile(
        r"^\s*(La\s+Ballade\s+de\s+Pern\s*[-–—]\s*)?(TOME\s+\d{1,2})\s+(.+?)\s*$",
        re.IGNORECASE
    ),
]


# =========================
# HELPERS
# =========================

def normalize_line(s: str) -> str:
    s = s.replace("\u00ad", "")
    s = s.replace("\ufeff", "")
    s = s.replace("\u200b", "")
    s = s.replace("’", "'")
    s = re.sub(r"[ \t]+", " ", s)
    return s.strip()


def looks_like_header_footer(line: str) -> bool:
    if not line:
        return True
    if PRINTED_PAGE_PATTERN.fullmatch(line) and len(line) <= 4:
        return True
    return False


def update_structure(line: str, current: Dict[str, Optional[str]]) -> None:
    for pat in PART_PATTERNS:
        if pat.match(line):
            current["part"] = line
            current["chapter"] = None
            return

    for pat in CHAPTER_PATTERNS:
        m = pat.match(line)
        if m:
            chap = m.group(1) if m.groups() else line
            current["chapter"] = f"Chapter {chap}"
            return


def extract_tome_title(line: str) -> Optional[str]:
    """
    Return a normalized tome title if the line looks like a tome heading.
    Example output:
    La Ballade de Pern - Tome 1 L'AUBE DES DRAGONS
    """
    l = normalize_line(line)

    for pat in TOME_PATTERNS:
        m = pat.match(l)
        if not m:
            continue

        groups = m.groups()

        # pattern 1: prefix, number, title
        if len(groups) == 3 and groups[1].isdigit():
            tome_num = groups[1]
            tome_title = groups[2].strip(" -–—:")
            return f"La Ballade de Pern - Tome {tome_num} {tome_title}"

        # pattern 2: prefix, "TOME X", title
        if len(groups) == 3:
            tome_label = groups[1].strip()
            tome_title = groups[2].strip(" -–—:")
            return f"La Ballade de Pern - {tome_label.title()} {tome_title}"

    return None


# =========================
# PDF -> TEXT PER PAGE
# =========================

def pdf_to_pages(pdf_path: Path) -> List[str]:
    if not pdf_path.exists():
        raise FileNotFoundError(f"PDF not found: {pdf_path.resolve()}")

    with tempfile.TemporaryDirectory() as td:
        out_txt = Path(td) / "out.txt"

        result = subprocess.run(
            ["pdftotext", "-layout", str(pdf_path), str(out_txt)],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )

        if result.returncode != 0:
            raise RuntimeError(
                f"pdftotext failed for {pdf_path}\n"
                f"Return code: {result.returncode}\n"
                f"stderr:\n{result.stderr}"
            )

        full_text = out_txt.read_text(encoding="utf-8", errors="replace")

    pages = full_text.split("\f")
    if pages and not pages[-1].strip():
        pages = pages[:-1]
    return pages


# =========================
# REFLOW WITH PAGE PROVENANCE
# =========================

SENTENCE_END_RE = re.compile(r"[.!?…]+[\"”’»)]?\s*$")
DIALOGUE_DASH_RE = re.compile(r"^\s*[-–—]\s*")
HARD_BREAK_RE = re.compile(r"^\s*$")


def should_join_with_space(prev: str, cur: str) -> bool:
    if not prev:
        return False
    if SENTENCE_END_RE.search(prev):
        return False
    if DIALOGUE_DASH_RE.match(cur):
        return False
    return True


def reflow_pages_with_provenance(
    page_texts: List[str],
    drop_headers_footers: bool = True,
    drop_empty: bool = True,
) -> List[Dict[str, Any]]:
    chunks: List[Dict[str, Any]] = []

    current_text = ""
    current_start_page = 1
    current_end_page = 1
    prev_line = ""

    for i, page_text in enumerate(page_texts):
        pdf_page = i + 1
        raw_lines = page_text.splitlines()

        lines = [normalize_line(x) for x in raw_lines]

        if drop_headers_footers:
            lines = [x for x in lines if not looks_like_header_footer(x)]

        if drop_empty:
            lines = [x for x in lines if x]

        for l in lines:
            if not l:
                continue

            if not current_text:
                current_text = l
                current_start_page = pdf_page
                current_end_page = pdf_page
                prev_line = l
                continue

            # hyphenation across line break
            if prev_line.endswith("-") and not prev_line.endswith(" -"):
                current_text = current_text[:-1] + l
            elif should_join_with_space(prev_line, l):
                current_text += " " + l
            else:
                current_text += "\n" + l

            prev_line = l
            current_end_page = pdf_page

        if current_text.strip() and SENTENCE_END_RE.search(current_text.splitlines()[-1]):
            chunks.append({
                "text": current_text.strip(),
                "start_pdf_page": current_start_page,
                "end_pdf_page": current_end_page
            })
            current_text = ""
            prev_line = ""
            current_start_page = pdf_page + 1
            current_end_page = pdf_page + 1

    if current_text.strip():
        chunks.append({
            "text": current_text.strip(),
            "start_pdf_page": current_start_page,
            "end_pdf_page": current_end_page
        })

    return chunks


# =========================
# BUILD SENTENCE TABLE
# =========================

def build_sentences_table(
    page_texts: List[str],
    default_book_title: str = "La Ballade de Pern",
    keep_headers_footers: bool = False,
    keep_empty: bool = False,
) -> pd.DataFrame:
    current = {
        "part": None,
        "chapter": None,
        "book": default_book_title,
    }

    page_struct: Dict[int, Dict[str, Optional[str]]] = {}

    # Scan each page in order to detect tome / part / chapter metadata
    for i, ptxt in enumerate(page_texts):
        pdf_page = i + 1
        raw_lines = ptxt.splitlines()
        norm_lines = [normalize_line(x) for x in raw_lines]

        for l in norm_lines:
            if not l:
                continue

            tome_title = extract_tome_title(l)
            if tome_title:
                current["book"] = tome_title

            update_structure(l, current)

        page_struct[pdf_page] = {
            "book": current["book"],
            "part": current["part"],
            "chapter": current["chapter"],
        }

    chunks = reflow_pages_with_provenance(
        page_texts=page_texts,
        drop_headers_footers=not keep_headers_footers,
        drop_empty=not keep_empty,
    )

    rows: List[Dict[str, Any]] = []
    sent_id = 0

    for ch in tqdm(chunks, desc="Sentence splitting"):
        text = ch["text"]
        start_p = int(ch["start_pdf_page"])
        end_p = int(ch["end_pdf_page"])

        meta = page_struct.get(start_p, {})
        book = meta.get("book", default_book_title)
        part = meta.get("part")
        chapter = meta.get("chapter")

        doc = nlp(text.replace("\n", " "))

        for s in doc.sents:
            sent = s.text.strip()
            if not sent:
                continue

            sent_id += 1
            rows.append(
                {
                    "sentence_id": sent_id,
                    "book": book,               # <- tome title stored here
                    "part": part,
                    "chapter": chapter,
                    "pdf_page": start_p,        # <- single page column
                    "start_pdf_page": start_p,
                    "end_pdf_page": end_p,
                    "text": sent,
                }
            )

    return pd.DataFrame(rows)


# =========================
# PIPELINE
# =========================

def run_pipeline(
    input_pdf: Path,
    out_dir: Path = Path("outputs"),
    default_book_title: str = "La Ballade de Pern",
    keep_headers_footers: bool = False,
    keep_empty: bool = False,
):
    out_dir.mkdir(parents=True, exist_ok=True)

    page_texts = pdf_to_pages(input_pdf)

    df = build_sentences_table(
        page_texts=page_texts,
        default_book_title=default_book_title,
        keep_headers_footers=keep_headers_footers,
        keep_empty=keep_empty,
    )

    out_csv = out_dir / f"{input_pdf.stem}.sentences_with_pages.csv"
    df.to_csv(out_csv, index=False, encoding="utf-8")

    print(f"Sentences: {len(df):,}")
    print(f"CSV: {out_csv}")

    return df

# %%
from pathlib import Path

df = run_pipeline(
    input_pdf=Path("La-ballade-de-Pern-intégrale-McCaffrey_-Anne-La-Ballade-de-Pern_-2015-12-21-9782823821758-bc3525592e.pdf"),
    out_dir=Path("outputs"),
    default_book_title="La Ballade de Pern"
)

df.head()
# Out:
# Sentence splitting: 100%|███████████████████| 2855/2855 [02:07<00:00, 22.41it/s]
# Sentences: 129,971
# CSV: outputs/La-ballade-de-Pern-intégrale-McCaffrey_-Anne-La-Ballade-de-Pern_-2015-12-21-9782823821758-bc3525592e.sentences_with_pages.csv
# Parquet: outputs/La-ballade-de-Pern-intégrale-McCaffrey_-Anne-La-Ballade-de-Pern_-2015-12-21-9782823821758-bc3525592e.sentences_with_pages.parquet
#    sentence_id                book  part chapter  pdf_page  start_pdf_page  \
# 0            1  La Ballade de Pern  None    None         4               4
# 1            2  La Ballade de Pern  None    None         4               4
# 2            3  La Ballade de Pern  None    None         4               4
# 3            4  La Ballade de Pern  None    None         4               4
# 4            5  La Ballade de Pern  None    None         4               4
#
#    end_pdf_page                                       text
# 0             8                                    SCIENCE
# 1             8                                          -
# 2             8                                    FICTION
# 3             8  Collection dirigée par Bénédicte Lombardo
# 4             8                                       ANNE
